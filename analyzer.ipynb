# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("input.txt")

# %% [markdown]
# ### Sort the data by keypresses

# %%
# sort by presses
df.sort_values(by=['presses'], inplace=True, ascending=False)
df.head()

# find the total presses
total = df['presses'].sum()
total

# create a new percent column
# this tells you what percent of presses the key
# makes up
percent = []
for presses in df['presses']:
    percent.append(presses/total)
df['percent'] = percent


df.head()
# Out:
#           key  presses   percent
# 56  Backspace     1085  0.133243
# 32      Space      866  0.106349
# 10          E      540  0.066315
# 58          T      481  0.059069
# 30          S      426  0.052315

# %% [markdown]
# ### Displays the number of key presses

# %%
sns.set_theme(style='darkgrid', rc={'figure.dpi': 150},              
              font_scale=1)

fig = sns.barplot(x = df["key"] , y = df["presses"])

fig.set_xticklabels(fig.get_xticklabels(),rotation = 90)
fig.set_title("Number Presses Per Key")

fig
# Out:
# <AxesSubplot:title={'center':'Number Presses Per Key'}, xlabel='key', ylabel='presses'>

# %%
# sort the dataframe by letters
# more specifically since all the letters have length of
# 1 we can get all the keys with length 1
letters_df = df[df.key.str.len() == 1]

letters_fig = sns.barplot(x = "key" , y = "presses", data=letters_df)

letters_fig.set_xticklabels(letters_fig.get_xticklabels(),rotation = 90)
letters_fig.set_title("Number Presses Per Key")

letters_fig
# Out:
# <AxesSubplot:title={'center':'Number Presses Per Key'}, xlabel='key', ylabel='presses'>

# %%
# similarly we can do it by not letters
other_df = df[df.key.str.len() > 1]
other_fig = sns.barplot(x = "key" , y = "presses", data=other_df)
other_fig.set_xticklabels(other_fig.get_xticklabels(),rotation = 90)
other_fig.set_title("Number Presses Per Key")
other_fig
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12596/521001449.py in <module>
#       2 other_df = df[df.key.str.len() > 1]
#       3 other_fig = sns.barplot(x = "key" , y = "presses", data=other_df)
# ----> 4 other_fig.set_xticklabels(letters_fig.get_xticklabels(),rotation = 90)
#       5 other_fig.set_title("Number Presses Per Key")
#       6 other_fig
#
# c:\Users\albar\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\axes\_base.py in wrapper(self, *args, **kwargs)
#      73
#      74         def wrapper(self, *args, **kwargs):
# ---> 75             return get_method(self)(*args, **kwargs)
#      76
#      77         wrapper.__module__ = owner.__module__
#
# c:\Users\albar\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\axis.py in _set_ticklabels(self, labels, fontdict, minor, **kwargs)
#    1796         if fontdict is not None:
#    1797             kwargs.update(fontdict)
# -> 1798         return self.set_ticklabels(labels, minor=minor, **kwargs)
#    1799
#    1800     def _set_tick_locations(self, ticks, *, minor=False):
#
# c:\Users\albar\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\axis.py in set_ticklabels(self, ticklabels, minor, **kwargs)
#    1718             # remove all tick labels, so only error for > 0 ticklabels
#    1719             if len(locator.locs) != len(ticklabels) and len(ticklabels) != 0:
# -> 1720                 raise ValueError(
#    1721                     "The number of FixedLocator locations"
#    1722                     f" ({len(locator.locs)}), usually from a call to"
#
# ValueError: The number of FixedLocator locations (33), usually from a call to set_ticks, does not match the number of ticklabels (26).
